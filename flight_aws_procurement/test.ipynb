# %%
import boto3
import gzip
import pandas as pd
from io import BytesIO
import json

# %%
s3_client = boto3.client('s3')

# %%
response = s3_client.get_object(Bucket='atc-speech-recognition', Key='readsb-hist/2022/01/08/000000Z.json.gz')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <module>
# ----> 1 response = s3_client.get_object(Bucket='atc-speech-recognition', Key='readsb-hist/2022/01/08/000000Z.json.gz')
#
# NameError: name 's3_client' is not defined

# %%
s3 = boto3.resource("s3")
obj = s3.Object("atc-speech-recognition", "readsb-hist/2022/01/08/054800Z.json.gz")
with gzip.GzipFile(fileobj=obj.get()["Body"]) as gzipfile:
    content = gzipfile.read()

# %%
json_file = json.loads(content)['aircraft']

# %%
df = pd.DataFrame.from_dict(json_file)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5082 entries, 0 to 5081
# Data columns (total 56 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   hex               5082 non-null   object
#  1   type              5082 non-null   object
#  2   r                 4400 non-null   object
#  3   t                 4359 non-null   object
#  4   alt_baro          4803 non-null   object
#  5   alt_geom          3212 non-null   float64
#  6   gs                4407 non-null   float64
#  7   track             3799 non-null   float64
#  8   baro_rate         3139 non-null   float64
#  9   lastPosition      378 non-null    object
#  10  sil_type          4712 non-null   object
#  11  mlat              5082 non-null   object
#  12  tisb              5082 non-null   object
#  13  messages          5082 non-null   int64
#  14  seen              5082 non-null   float64
#  15  rssi              5082 non-null   float64
#  16  flight            4422 non-null   object
#  17  squawk            3885 non-null   object
#  18  emergency         3119 non-null   object
#  19  category          4141 non-null   object
#  20  nav_qnh           2966 non-null   float64
#  21  nav_altitude_mcp  2972 non-null   float64
#  22  nav_heading       1630 non-null   float64
#  23  lat               4336 non-null   float64
#  24  lon               4336 non-null   float64
#  25  nic               4336 non-null   float64
#  26  rc                4336 non-null   float64
#  27  seen_pos          4336 non-null   float64
#  28  version           4217 non-null   float64
#  29  nic_baro          2835 non-null   float64
#  30  nac_p             4226 non-null   float64
#  31  nac_v             3975 non-null   float64
#  32  sil               4226 non-null   float64
#  33  gva               2766 non-null   float64
#  34  sda               3315 non-null   float64
#  35  alert             3840 non-null   float64
#  36  spi               3840 non-null   float64
#  37  nav_modes         375 non-null    object
#  38  dbFlags           78 non-null     float64
#  39  geom_rate         2037 non-null   float64
#  40  true_heading      2111 non-null   float64
#  41  ias               1723 non-null   float64
#  42  tas               1699 non-null   float64
#  43  mach              1721 non-null   float64
#  44  wd                1500 non-null   float64
#  45  ws                1500 non-null   float64
#  46  oat               1473 non-null   float64
#  47  tat               1473 non-null   float64
#  48  track_rate        1520 non-null   float64
#  49  roll              1703 non-null   float64
#  50  mag_heading       1737 non-null   float64
#  51  nav_altitude_fms  467 non-null    float64
#  52  calc_track        64 non-null     float64
#  53  gpsOkBefore       11 non-null     float64
#  54  rr_lat            275 non-null    float64
#  55  rr_lon            275 non-null    float64
# dtypes: float64(41), int64(1), object(14)
# memory usage: 2.2+ MB

# %%
df.to_csv('test', index=False)

# %%
df[(df['lat']-32.8998)**2+(df['lon']+97.0403)**2<6.25]
# Out:
#          hex       type    flight       r     t alt_baro  alt_geom     gs  \
# 2230  a289ec  adsb_icao  N2628S    N2628S  C337     9600    9650.0  162.4
# 2235  a1716c  adsb_icao  JUS192    N192US  DC91    34000   34925.0  424.1
# 2238  ad0520  adsb_icao  FTH938    N938TX  C750    43000   44100.0  481.3
# 2269  ac9ec4  adsb_icao  N912GW    N912GW  C25A    41000   41975.0  435.8
# 2273  a93ac8  adsb_icao  NKS1466   N694NK  A320    39025   40025.0  480.4
# ...      ...        ...       ...     ...   ...      ...       ...    ...
# 2783  a64d1e  adsb_icao  N505GE    N505GE  BE60     8300    8500.0  184.8
# 2797  aa234a  adsb_icao  AAL1043   N752US  A319    36075   36925.0  453.8
# 2812  a36f9d  adsb_icao  N320PH    N320PH  EC35     1150    1275.0   96.0
# 2822  a448d7  adsb_icao  UAL745    N37508  B39M    34000   34950.0  472.0
# 2827  aad762  adsb_icao  SWA1830   N798SW  B737    37000   37925.0  465.8
#
#        track  baro_rate  ...  wd  ws oat  tat  track_rate  roll  mag_heading  \
# 2230  130.75        NaN  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 2235  271.35        0.0  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 2238  287.91        0.0  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 2269  125.00        NaN  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 2273  109.45        0.0  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# ...      ...        ...  ...  ..  ..  ..  ...         ...   ...          ...
# 2783  345.59        NaN  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 2797   83.67     1280.0  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 2812  180.60      512.0  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 2822  306.99        0.0  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 2827  101.77        0.0  ... NaN NaN NaN  NaN         NaN   NaN          NaN
#
#       rr_lat  rr_lon  gpsOkBefore
# 2230     NaN     NaN          NaN
# 2235     NaN     NaN          NaN
# 2238     NaN     NaN          NaN
# 2269     NaN     NaN          NaN
# 2273     NaN     NaN          NaN
# ...      ...     ...          ...
# 2783     NaN     NaN          NaN
# 2797     NaN     NaN          NaN
# 2812     NaN     NaN          NaN
# 2822     NaN     NaN          NaN
# 2827     NaN     NaN          NaN
#
# [216 rows x 56 columns]

# %%
df[df['lon']<20]
# Out:
#          hex          type    flight       r     t alt_baro  alt_geom     gs  \
# 0     a7fa65     adsb_icao  FDX5285   N613FE  MD11    36025   35350.0  495.4
# 1     a806d8     adsb_icao  UPS64     N616UP  B748    38000   37275.0  497.7
# 2     a6456d     adsb_icao  DAL27     N503DN  A359    38000   37000.0  524.2
# 3     a4c34c     adsb_icao  DAL197    N406DX  A339    36000   35025.0  520.2
# 4     a31a54     adsb_icao  UAL893    N29975  B789    37000   36000.0  522.1
# ...      ...           ...       ...     ...   ...      ...       ...    ...
# 6315  474805  adsb_icao_nt  TXLU04       NaN   NaN   ground       NaN    NaN
# 6316  4d010b     adsb_icao  ICV8799   LX-VCV  B744    34000   33350.0  453.8
# 6317  471f75     adsb_icao  WZZ84WX   HA-LXT  A321    39025   38350.0  450.5
# 6318  471f64     adsb_icao  WZZ1EE    HA-LXC  A321     2025    2275.0  155.0
# 6319  471f56     adsb_icao  WZZ86CF   HA-LWO  A320    39050   38200.0  452.1
#
#        track  baro_rate  ...     wd    ws   oat   tat  track_rate  roll  \
# 0     249.81        0.0  ...    NaN   NaN   NaN   NaN         NaN   NaN
# 1     249.78        0.0  ...    NaN   NaN   NaN   NaN         NaN   NaN
# 2     278.11        0.0  ...    NaN   NaN   NaN   NaN         NaN   NaN
# 3     278.85        0.0  ...    NaN   NaN   NaN   NaN         NaN   NaN
# 4     268.79        NaN  ...    NaN   NaN   NaN   NaN         NaN   NaN
# ...      ...        ...  ...    ...   ...   ...   ...         ...   ...
# 6315     NaN        NaN  ...    NaN   NaN   NaN   NaN         NaN   NaN
# 6316  278.36        0.0  ...  228.0  31.0 -57.0 -28.0       -0.03 -0.35
# 6317  119.52      -64.0  ...  226.0  34.0 -55.0 -29.0       -0.03 -0.35
# 6318  312.65     -704.0  ...  109.0   9.0   NaN   NaN        0.28  0.18
# 6319  116.40        0.0  ...  227.0  46.0 -57.0 -31.0        0.00  0.00
#
#       mag_heading  rr_lat  rr_lon  gpsOkBefore
# 0             NaN     NaN     NaN          NaN
# 1             NaN     NaN     NaN          NaN
# 2             NaN     NaN     NaN          NaN
# 3             NaN     NaN     NaN          NaN
# 4             NaN     NaN     NaN          NaN
# ...           ...     ...     ...          ...
# 6315          NaN     NaN     NaN          NaN
# 6316       270.53     NaN     NaN          NaN
# 6317       118.48     NaN     NaN          NaN
# 6318       308.67     NaN     NaN          NaN
# 6319       116.19     NaN     NaN          NaN
#
# [6165 rows x 56 columns]

# %%
df_combined = pd.DataFrame()

# %%
df_combined.append(df)
# Out:
#           hex          type    flight       r     t alt_baro  alt_geom     gs  \
# 0      a7fa65     adsb_icao  FDX5285   N613FE  MD11    36025   35350.0  495.4
# 1      a806d8     adsb_icao  UPS64     N616UP  B748    38000   37275.0  497.7
# 2      a6456d     adsb_icao  DAL27     N503DN  A359    38000   37000.0  524.2
# 3      a4c34c     adsb_icao  DAL197    N406DX  A339    36000   35025.0  520.2
# 4      a31a54     adsb_icao  UAL893    N29975  B789    37000   36000.0  522.1
# ...       ...           ...       ...     ...   ...      ...       ...    ...
# 8206   a37845        mode_s  N3221M    N3221M  BE9L   ground    7650.0    NaN
# 8207   461f4e        mode_s       NaN  OH-LWG  A359      NaN       NaN  360.6
# 8208   4846e7  adsb_icao_nt  OH67         NaN   NaN      NaN       NaN    NaN
# 8209   4243a3     adsb_icao       NaN  VP-BZC  E190      NaN       NaN  219.0
# 8210  ~338bce    tisb_other       NaN     NaN   NaN   ground       NaN   16.5
#
#        track  baro_rate  ...  wd  ws oat  tat  track_rate  roll  mag_heading  \
# 0     249.81        0.0  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 1     249.78        0.0  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 2     278.11        0.0  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 3     278.85        0.0  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 4     268.79        NaN  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# ...      ...        ...  ...  ..  ..  ..  ...         ...   ...          ...
# 8206     NaN        NaN  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 8207   65.07    -2368.0  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 8208     NaN        NaN  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 8209  359.74     -448.0  ... NaN NaN NaN  NaN         NaN   NaN          NaN
# 8210  312.19        NaN  ... NaN NaN NaN  NaN         NaN   NaN          NaN
#
#       rr_lat  rr_lon  gpsOkBefore
# 0        NaN     NaN          NaN
# 1        NaN     NaN          NaN
# 2        NaN     NaN          NaN
# 3        NaN     NaN          NaN
# 4        NaN     NaN          NaN
# ...      ...     ...          ...
# 8206    37.6  -106.1          NaN
# 8207    38.1   127.1          NaN
# 8208     NaN     NaN          NaN
# 8209     NaN     NaN          NaN
# 8210     NaN     NaN          NaN
#
# [8211 rows x 56 columns]

# %%
d = {'col1': [1, 2], 'col2': [3, 4], 'flight': ['yoyo','hello']}
df_2 = pd.DataFrame(data=d)

# %%
df.append(df_2)
# Out:
#           hex          type    flight       r     t alt_baro  alt_geom     gs  \
# 0      a7fa65     adsb_icao  FDX5285   N613FE  MD11    36025   35350.0  495.4
# 1      a806d8     adsb_icao  UPS64     N616UP  B748    38000   37275.0  497.7
# 2      a6456d     adsb_icao  DAL27     N503DN  A359    38000   37000.0  524.2
# 3      a4c34c     adsb_icao  DAL197    N406DX  A339    36000   35025.0  520.2
# 4      a31a54     adsb_icao  UAL893    N29975  B789    37000   36000.0  522.1
# ...       ...           ...       ...     ...   ...      ...       ...    ...
# 8208   4846e7  adsb_icao_nt  OH67         NaN   NaN      NaN       NaN    NaN
# 8209   4243a3     adsb_icao       NaN  VP-BZC  E190      NaN       NaN  219.0
# 8210  ~338bce    tisb_other       NaN     NaN   NaN   ground       NaN   16.5
# 0         NaN           NaN      yoyo     NaN   NaN      NaN       NaN    NaN
# 1         NaN           NaN     hello     NaN   NaN      NaN       NaN    NaN
#
#        track  baro_rate  ... oat tat track_rate  roll  mag_heading  rr_lat  \
# 0     249.81        0.0  ... NaN NaN        NaN   NaN          NaN     NaN
# 1     249.78        0.0  ... NaN NaN        NaN   NaN          NaN     NaN
# 2     278.11        0.0  ... NaN NaN        NaN   NaN          NaN     NaN
# 3     278.85        0.0  ... NaN NaN        NaN   NaN          NaN     NaN
# 4     268.79        NaN  ... NaN NaN        NaN   NaN          NaN     NaN
# ...      ...        ...  ...  ..  ..        ...   ...          ...     ...
# 8208     NaN        NaN  ... NaN NaN        NaN   NaN          NaN     NaN
# 8209  359.74     -448.0  ... NaN NaN        NaN   NaN          NaN     NaN
# 8210  312.19        NaN  ... NaN NaN        NaN   NaN          NaN     NaN
# 0        NaN        NaN  ... NaN NaN        NaN   NaN          NaN     NaN
# 1        NaN        NaN  ... NaN NaN        NaN   NaN          NaN     NaN
#
#       rr_lon  gpsOkBefore  col1  col2
# 0        NaN          NaN   NaN   NaN
# 1        NaN          NaN   NaN   NaN
# 2        NaN          NaN   NaN   NaN
# 3        NaN          NaN   NaN   NaN
# 4        NaN          NaN   NaN   NaN
# ...      ...          ...   ...   ...
# 8208     NaN          NaN   NaN   NaN
# 8209     NaN          NaN   NaN   NaN
# 8210     NaN          NaN   NaN   NaN
# 0        NaN          NaN   1.0   3.0
# 1        NaN          NaN   2.0   4.0
#
# [8213 rows x 58 columns]

# %%
df['time'] = json.loads(content)['now']

# %%
df
# Out:
#           hex          type    flight       r     t alt_baro  alt_geom     gs  \
# 0      a7fa65     adsb_icao  FDX5285   N613FE  MD11    36025   35350.0  495.4
# 1      a806d8     adsb_icao  UPS64     N616UP  B748    38000   37275.0  497.7
# 2      a6456d     adsb_icao  DAL27     N503DN  A359    38000   37000.0  524.2
# 3      a4c34c     adsb_icao  DAL197    N406DX  A339    36000   35025.0  520.2
# 4      a31a54     adsb_icao  UAL893    N29975  B789    37000   36000.0  522.1
# ...       ...           ...       ...     ...   ...      ...       ...    ...
# 8206   a37845        mode_s  N3221M    N3221M  BE9L   ground    7650.0    NaN
# 8207   461f4e        mode_s       NaN  OH-LWG  A359      NaN       NaN  360.6
# 8208   4846e7  adsb_icao_nt  OH67         NaN   NaN      NaN       NaN    NaN
# 8209   4243a3     adsb_icao       NaN  VP-BZC  E190      NaN       NaN  219.0
# 8210  ~338bce    tisb_other       NaN     NaN   NaN   ground       NaN   16.5
#
#        track  baro_rate  ...  ws oat tat  track_rate  roll  mag_heading  \
# 0     249.81        0.0  ... NaN NaN NaN         NaN   NaN          NaN
# 1     249.78        0.0  ... NaN NaN NaN         NaN   NaN          NaN
# 2     278.11        0.0  ... NaN NaN NaN         NaN   NaN          NaN
# 3     278.85        0.0  ... NaN NaN NaN         NaN   NaN          NaN
# 4     268.79        NaN  ... NaN NaN NaN         NaN   NaN          NaN
# ...      ...        ...  ...  ..  ..  ..         ...   ...          ...
# 8206     NaN        NaN  ... NaN NaN NaN         NaN   NaN          NaN
# 8207   65.07    -2368.0  ... NaN NaN NaN         NaN   NaN          NaN
# 8208     NaN        NaN  ... NaN NaN NaN         NaN   NaN          NaN
# 8209  359.74     -448.0  ... NaN NaN NaN         NaN   NaN          NaN
# 8210  312.19        NaN  ... NaN NaN NaN         NaN   NaN          NaN
#
#       rr_lat  rr_lon  gpsOkBefore          time
# 0        NaN     NaN          NaN  1.641600e+09
# 1        NaN     NaN          NaN  1.641600e+09
# 2        NaN     NaN          NaN  1.641600e+09
# 3        NaN     NaN          NaN  1.641600e+09
# 4        NaN     NaN          NaN  1.641600e+09
# ...      ...     ...          ...           ...
# 8206    37.6  -106.1          NaN  1.641600e+09
# 8207    38.1   127.1          NaN  1.641600e+09
# 8208     NaN     NaN          NaN  1.641600e+09
# 8209     NaN     NaN          NaN  1.641600e+09
# 8210     NaN     NaN          NaN  1.641600e+09
#
# [8211 rows x 57 columns]

# %%
import boto3
import gzip
import json
import pandas as pd

def main():
    s3 = boto3.resource("s3")

    df_combined = pd.DataFrame()

    for hour in range(24):
        hour = f"{hour:02}"
        df_hour = pd.DataFrame()
        for minute in range(60):
            minute = f"{minute:02}"
            for second in range(12): # Data increments by 5 seconds
                second = f"{second*5:02}"
                time_str = "readsb-hist/2022/01/08/" + hour + minute + second + "Z.json.gz"
                df_combined = df_combined.append(get_df(s3, time_str))
                df_hour = df_hour.append(get_df(s3, time_str))
        df_hour.to_csv(hour, index=False)
        
    
    df_combined.to_csv('01-08-2022', index=False)

def get_df(s3_instance, time_str):
    obj = s3_instance.Object("atc-speech-recognition", time_str)
    with gzip.GzipFile(fileobj=obj.get()["Body"]) as gzipfile:
        content = gzipfile.read()
        json_file = json.loads(content)['aircraft']

        df = pd.DataFrame.from_dict(json_file)
        df['time'] = json.loads(content)['now']
        return df[(df['lat']-32.8998)**2+(df['lon']+97.0403)**2<6.25]

if __name__ == "__main__":
    main()
